# %%
Cron jobs :  
############# 
* * * * *  
1. Minute 
2. Hour  
3. Day 
4. Month  
5. Weekday 

1. If I want to run this query everyday @ 8'o clock ?  
Ans : 00 08 * * *  

2. If I want to run a report at morning 8'o clock and evening 8'o clock ?  
Ans : 00 08,20 * * * 
    
3. If I want to run a report at everyday at 8:30 AM ?  
Ans :30 08 * * * 

4. If I want to run a report for everyhour from morning 8'o clock to evening 8'o clock ? 
Ans : 00 08-20 * * * 

5. If I want to run a report everyday 8'o clock on business day ?  
Ans : 00 08 * * 1-5  
Bussiness hours:  
Monday - Friday  
Monday - 1  
Tuesday - 2 
Wed - 3 
Thur - 4 
Fri -5  
Sat -6  
Sun - 0 

6. If I want to run a report at evening 6PM on saturday and sunday ?  
Ans : 00 18 * * 6,0 

7. If I want to run a report only on 1st of month and 15th of month at 8'o clock ? 
Ans : 00 08 1,15 * *  

8. If I want to run a report on every 5 minutes ?  
Ans : */5 * * * * 

Website : https://crontab.guru/
