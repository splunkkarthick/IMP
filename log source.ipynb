# %%
| SL No | Application / Device              | Source Types                                                                                                                                                                                                                                                                        | Collection Method  | Index Name        | Add-on URL                                                                       |
| ----: | --------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------ | ----------------- | -------------------------------------------------------------------------------- |
|     1 | PaloAlto Firewall                 | `pan:config`, `pan:globalprotect`, `pan:system`, `pan:threat`, `pan:traffic`, `pan:userid`                                                                                                                                                                                          | Syslog Forwarding  | `paloalto`        | [https://splunkbase.splunk.com/app/2757](https://splunkbase.splunk.com/app/2757) |
|     2 | Forcepoint Firewall               | `next-generation-firewall`                                                                                                                                                                                                                                                          | Syslog Forwarding  | `forcepoint`      | NA                                                                               |
|     3 | Paloalto Prisma Firewall          | `pan:firewall_cloud`                                                                                                                                                                                                                                                                | Splunk HEC         | `paloalto_prisma` | [https://splunkbase.splunk.com/app/2757](https://splunkbase.splunk.com/app/2757) |
|     4 | Cisco Switches                    | `cisco:ios`                                                                                                                                                                                                                                                                         | Syslog Forwarding  | `cisco`           | [https://splunkbase.splunk.com/app/1467](https://splunkbase.splunk.com/app/1467) |
|     5 | Cisco Router                      | `cisco:ise:syslog`                                                                                                                                                                                                                                                                  | Syslog Forwarding  | `cisco`           | [https://splunkbase.splunk.com/app/1467](https://splunkbase.splunk.com/app/1467) |
|     6 | Cisco WLC                         | `cisco:ios`                                                                                                                                                                                                                                                                         | Syslog Forwarding  | `cisco`           | [https://splunkbase.splunk.com/app/1467](https://splunkbase.splunk.com/app/1467) |
|     7 | Cisco DNAC                        | `cisco:dnac:syslog`                                                                                                                                                                                                                                                                 | Syslog Forwarding  | `cisco_dnac`      | NA                                                                               |
|     8 | IIS Web Server                    | `ms:iis:splunk`                                                                                                                                                                                                                                                                     | File Monitoring    | `iis`             | [https://splunkbase.splunk.com/app/3185](https://splunkbase.splunk.com/app/3185) |
|     9 | Symantec EP                       | `symantec:ep:admin:file`, `symantec:ep:agent:file`, `symantec:ep:agt_system:file`, `symantec:ep:behavior:file`, `symantec:ep:policy:file`, `symantec:ep:risk:file`, `symantec:ep:scan:file`, `symantec:ep:scm_system:file`, `symantec:ep:security:file`, `symantec:ep:traffic:file` | File Monitoring    | `symantec`        | [https://splunkbase.splunk.com/app/2772](https://splunkbase.splunk.com/app/2772) |
|    10 | Forcepoint DLP                    | `forcepoint:dlp`                                                                                                                                                                                                                                                                    | File Monitoring    | `dlp`             | [https://splunkbase.splunk.com/app/5417](https://splunkbase.splunk.com/app/5417) |
|    11 | Crowdstrike Devices               | `crowdstrike:device:json`                                                                                                                                                                                                                                                           | Modular Input      | `crowdstrike`     | [https://splunkbase.splunk.com/app/5570](https://splunkbase.splunk.com/app/5570) |
|    12 | Crowdstrike Events/Incidents      | `CrowdStrike:Event:Streams:JSON`                                                                                                                                                                                                                                                    | Modular Input      | `crowdstrike`     | [https://splunkbase.splunk.com/app/5082](https://splunkbase.splunk.com/app/5082) |
|    13 | Netskope CASB                     | `netskope:alert`, `netskope:application`, `netskope:audit`, `netskope:clients`, `netskope:connection`                                                                                                                                                                               | Modular Input      | `netskope`        | [https://splunkbase.splunk.com/app/3808](https://splunkbase.splunk.com/app/3808) |
|    14 | Salesforce                        | `sfdc:account`, `sfdc:logfile`, `sfdc:loginhistory`, `sfdc:opportunity`, `sfdc:report`, `sfdc:user`, `sfdc:dashboard`                                                                                                                                                               | Modular Input      | `salesforce`      | [https://splunkbase.splunk.com/app/3549](https://splunkbase.splunk.com/app/3549) |
|    15 | Qualys                            | `qualys:activityLog`, `qualys:hostDetection`, `qualys:knowledgebase`, `qualys:wasFindings`, `qualys:pc:policyInfo`, `qualys:pc:postureInfo`, `qualys:pcrs:policyInfo`, `qualys:pcrs:policy_summary`, `qualys:pcrs:postureInfo`                                                      | Modular Input      | `qualys`          | [https://splunkbase.splunk.com/app/2964](https://splunkbase.splunk.com/app/2964) |
|    16 | Windows                           | `WinEventLog:Application`, `WinEventLog:Security`, `WinEventLog:System`                                                                                                                                                                                                             | Modular Input      | `windows`         | [https://splunkbase.splunk.com/app/742](https://splunkbase.splunk.com/app/742)   |
|    17 | DNS                               | `MSAD:NT6:DNS`                                                                                                                                                                                                                                                                      | File Monitoring    | `windows`         | [https://splunkbase.splunk.com/app/742](https://splunkbase.splunk.com/app/742)   |
|    18 | DHCP                              | `DhcpSrvLog`                                                                                                                                                                                                                                                                        | File Monitoring    | `windows`         | [https://splunkbase.splunk.com/app/742](https://splunkbase.splunk.com/app/742)   |
|    19 | Linux                             | `linux_secure`, `syslog`, `cron`                                                                                                                                                                                                                                                    | File Monitoring    | `nix`             | [https://splunkbase.splunk.com/app/833](https://splunkbase.splunk.com/app/833)   |
|    20 | AWS                               | `aws:cloudtrail`, `aws:cloudwatch`, `aws:cloudwatch:guardduty`, `aws:cloudwatchlogs:vpcflow`, `aws:config`, `aws:config:rule`, `aws:metadata`, `aws:s3:accesslogs`, `aws:securityhub:finding`, `aws:accessanalyzer:finding`                                                         | Modular Input, HEC | `aws_security`    | [https://splunkbase.splunk.com/app/1876](https://splunkbase.splunk.com/app/1876) |
|    21 | Microsoft Azure                   | `azure:aad:user`, `azure:aad:audit`, `azure:aad:signin`, `azure:aad:identity_protection:risk_detection`                                                                                                                                                                             | Modular Input      | `azure`           | [https://splunkbase.splunk.com/app/3757](https://splunkbase.splunk.com/app/3757) |
|    22 | Microsoft Office 365              | `o365:management:activity`, `o365:reporting:messagetrace`                                                                                                                                                                                                                           | Modular Input      | `o365`            | [https://splunkbase.splunk.com/app/4055](https://splunkbase.splunk.com/app/4055) |
|    23 | Microsoft Office 365 Security HUB | `ms365:defender:incident`, `ms365:defender:incident:alerts`                                                                                                                                                                                                                         | Modular Input      | `o365`            | [https://splunkbase.splunk.com/app/6207](https://splunkbase.splunk.com/app/6207) |
|    24 | Microsoft Cloud Services          | `mscs:azure:audit`                                                                                                                                                                                                                                                                  | Modular Input      | `o365`            | [https://splunkbase.splunk.com/app/3110](https://splunkbase.splunk.com/app/3110) |
|    25 | TMS                               | `tms_loginlogs`, `tms_af_deal`, `tms_a_deal`, `tms_deals`, `tms_fxdeals`                                                                                                                                                                                                            | DB Connect Inputs  | `tms`             | [https://splunkbase.splunk.com/app/2686](https://splunkbase.splunk.com/app/2686) |
|    26 | MSSQL                             | `mssql:errorlog`, `mssql:agentlog`                                                                                                                                                                                                                                                  | File Monitoring    | `windows`         | [https://splunkbase.splunk.com/app/2648](https://splunkbase.splunk.com/app/2648) |
|    27 | Middleware EBS/Fiorano            | `fiorano_access`, `fiorano_audit`                                                                                                                                                                                                                                                   | File Monitoring    | `fiorano`         | Custom Data                                                                      |
|    28 | Swift                             | `swift_snmptraps`                                                                                                                                                                                                                                                                   | File Monitoring    | `swift`           | Custom Data                                                                      |
|    29 | Core Banking                      | `cb_account_balance`, `cb_audit`, `cb_deposit_history_transaction`, `cb_history_transaction`, `cb_transaction`                                                                                                                                                                      | DB Inputs          | `core_banking`    | Custom Data                                                                      |
|    30 | Internet Banking                  | `eb_login_ip`, `eb_transaction_details`, `eb_transaction_header`, `eb_transaction_request_details`, `eb_transaction_request_header`, `ebanking_beneficiary_details`, `ebanking_limit_history`                                                                                       | DB Inputs          | `e_banking`       | Custom Data                                                                      |
|    31 | Oracle RDS                        | `oracle:alert:text`, `oracle:audit:text`                                                                                                                                                                                                                                            | DB Connect Inputs  | `oraclerds`       | [https://splunkbase.splunk.com/app/1910](https://splunkbase.splunk.com/app/1910) |
