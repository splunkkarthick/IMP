# %%
TOP 20 USE CASES FOR WINDOWS AUTHENTICATION LOGS (WITH MITRE MAPPING)

(Best-practice list for SOC, SIEM, Splunk Security Admin, and Blue Team operations.)

🔐 1. Login From TOR Exit Node

MITRE:

Defense Evasion (TA0005)

Proxy/Anonymization (T1090.003)

Logic:
Detect any successful/failed login from a TOR IP.

🔥 2. Brute Force Attack (High Volume Failed Logons)

MITRE:

Credential Access (TA0006)

Brute Force (T1110)

Logic:
Multiple failed 4625 events within short time window.

🔁 3. Password Spraying (Different Users, Same Source IP)

MITRE:

Credential Access (TA0006)

Password Spraying (T1110.003)

Logic:
1 IP trying many usernames with 1–2 failed attempts each.

🔑 4. Successful Login After Multiple Failures (Brute Force Success)

MITRE:

Initial Access (TA0001)

Valid Accounts (T1078)

Logic:
4624 immediately after multiple 4625 events.

🕒 5. Impossible Travel Login (Geo-based Anomaly)

MITRE:

Defense Evasion (TA0005)

Valid Accounts (T1078)

Logic:
User logs in from two countries too far apart in unrealistic time.

🎭 6. Suspicious Logon Times (After Hours Activity)

MITRE:

Discovery (TA0007)

Initial Access (TA0001)

Logic:
User logs in outside business hours.

🧑‍💻 7. Privileged Account Login (Admin, Domain Admin, Enterprise Admin)

MITRE:

Privilege Escalation (TA0004)

Valid Accounts (T1078)

Logic:
Monitor all 4624 logons for privileged accounts.

🚪 8. Lateral Movement via RDP Logon (Logon Type 10)

MITRE:

Lateral Movement (TA0008)

Remote Desktop Protocol (T1021.001)

Logic:
Detect RDP logons between internal systems.

🔍 9. Service Account Interactive Login (Should Never Happen)

MITRE:

Defense Evasion (TA0005)

Valid Accounts (T1078)

Logic:
Service account logging in via interactive session (Type 2 or 10).

🚫 10. Disabled / Locked Account Login Attempt

MITRE:

Credential Access (TA0006)

Logic:
4625 event for disabled/locked-out user.

🧭 11. New Source IP Never Seen Before for a User

MITRE:

Defense Evasion (TA0005)

Valid Accounts (T1078)

Logic:
User logs in from an IP never used by them before.

🚨 12. Account Lockout Detection (Repeated Failed Logins)

MITRE:

Credential Access (TA0006)

Account Lockout Policy Abuse (T1110)

Logic:
Identify users who reached lockout thresholds.

🌍 13. Foreign Country Login Attempt

MITRE:

Defense Evasion (TA0005)

Logic:
User logging in from outside expected geo zones.

👤 14. Newly Created User Account Logon

MITRE:

Defense Evasion (TA0005)

Account Discovery (T1087)

Logic:
New user logs in within a short time after creation.

🛑 15. Shared Account Usage from Multiple Locations Simultaneously

MITRE:

Account Manipulation (T1098)

Valid Accounts (T1078)

Logic:
Same user logged in simultaneously from 2+ hosts.

🧪 16. Login From Anonymous Proxy or VPN Provider (Not TOR)

MITRE:

Defense Evasion (TA0005)

Logic:
Match with VPN/Proxy threat intel lists.

📦 17. High-Risk User Activity (Privileged or VIP accounts)

MITRE:
Depend on event combination

Logic:
Correlate authentication behavior with high-value users.

🔄 18. Logon Type Mismatch (Wrong Authentication Method)

MITRE:

Defense Evasion (TA0005)

Examples:

Admin logging in interactively instead of using RDP

Service accounts using Type 2 or 10

🕵️ 19. Logon Storm (Sudden Spike in Authentication Events)

MITRE:

Credential Access (TA0006)

Discovery (TA0007)

Logic:
High number of logons within short time window.

🛑 20. Login Using Expired Credentials

MITRE:

Credential Access (TA0006)

Logic:
4625 events with status code for expired password.
