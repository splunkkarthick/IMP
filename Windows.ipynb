# %%
WINDOWS ONBOARDING (Universal Forwarder Method)

1.1 Pre-Requisites

Install Splunk Universal Forwarder (UF).

Ensure service account has Read permissions on log files.

Open required ports:

8089 → UF Management

9997 → Data forwarding to Indexers

Prepare deployment configs:

inputs.conf

outputs.conf

serverclass.conf (if using Deployment Server)

deployment server IP

WINDOWS TEAM

Verification (Windows)

Check UF service:

services.msc → SplunkForwarder = Running


Validate logs:

splunkd.log (C:\Program Files\SplunkUniversalForwarder\var\log\splunk)


Check connectivity indexer and deployment server:

NC -ZV <indexer_ip> 9997
